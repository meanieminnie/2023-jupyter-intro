# %%
import pandas as pd

# %% [markdown]
# This is the website for all CFPB complaints: https://www.consumerfinance.gov/data-research/consumer-complaints/search/?company=Social%20Finance%2C%20Inc.&date_received_max=2023-05-20&date_received_min=2011-12-01&page=1&searchField=all&searchText=social%20finance%2C%20inc.&size=25&sort=created_date_desc&tab=List

# %%
#Import csv file with all complaints on CFPB website
df = pd.read_csv("complaints-2023-05-20_15_56.csv")
df
# Out:
#     Date received                                            Product  \
# 0        05/05/19                                       Student loan
# 1        06/06/22                        Checking or savings account
# 2        08/11/21                                           Mortgage
# 3        10/21/21          Payday loan, title loan, or personal loan
# 4        06/11/19                                    Debt collection
# ..            ...                                                ...
# 987      05/20/22                        Checking or savings account
# 988      05/24/22  Credit reporting, credit repair services, or o...
# 989      10/09/17                                       Student loan
# 990      04/05/22  Credit reporting, credit repair services, or o...
# 991      10/17/17  Credit reporting, credit repair services, or o...
#
#                         Sub-product  \
# 0              Private student loan
# 1                  Checking account
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 992 entries, 0 to 991
# Data columns (total 18 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   Date received                 992 non-null    object
#  1   Product                       992 non-null    object
#  2   Sub-product                   992 non-null    object
#  3   Issue                         992 non-null    object
#  4   Sub-issue                     992 non-null    object
#  5   Consumer complaint narrative  591 non-null    object
#  6   Company public response       992 non-null    object
#  7   Company                       992 non-null    object
#  8   State                         992 non-null    object
#  9   ZIP code                      992 non-null    object
#  10  Tags                          992 non-null    object
#  11  Consumer consent provided?    903 non-null    object
# ...

# %%
df["Consumer disputed?"].unique()
# Out:
# array([nan, 'No', 'Yes'], dtype=object)

# %%
dfY = df.query("`Consumer disputed?` == 'Yes'")
dfY
# Out:
#     Date received                  Product               Sub-product  \
# 207      11/24/15            Consumer Loan          Installment loan
# 410      11/09/16             Student loan  Non-federal student loan
# 426      03/02/16             Student loan  Non-federal student loan
# 436      12/07/16             Student loan  Non-federal student loan
# 481      03/13/14             Student loan  Non-federal student loan
# 564      06/03/16            Consumer Loan          Installment loan
# 593      02/24/17            Consumer Loan          Installment loan
# 633      02/04/16            Consumer Loan          Installment loan
# 634      08/29/16  Other financial service           Debt settlement
# 637      11/17/16             Student loan  Non-federal student loan
# 643      10/02/15             Student loan  Non-federal student loan
# 645      10/23/16            Consumer Loan          Installment loan
# 657      08/27/15             Student loan  Non-federal student loan
# ...

# %%
df.query("`Consumer disputed?` == 'No'")
# Out:
#     Date received                  Product                 Sub-product  \
# 151      06/08/16             Student loan    Non-federal student loan
# 168      11/23/15            Consumer Loan            Installment loan
# 298      11/05/16            Consumer Loan            Installment loan
# 300      11/01/16          Debt collection                 Credit card
# 384      10/27/15            Consumer Loan            Installment loan
# ..            ...                      ...                         ...
# 921      12/05/15            Consumer Loan            Installment loan
# 924      09/15/15  Bank account or service  Other bank product/service
# 940      09/27/14             Student loan    Non-federal student loan
# 953      02/04/15             Student loan    Non-federal student loan
# 966      03/10/15            Consumer Loan            Installment loan
#
#                                        Issue                 Sub-issue  \
# ...

# %% [markdown]
# Final Analysis: Out of the 992 complaints, 85 responded to the disputed section. 21 said they disputed the company's resolution of their complaints.
