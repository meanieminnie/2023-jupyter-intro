# %% [markdown]
# ## Pandas - Importing data
#
# Please download from Google Drive <a href="https://drive.google.com/file/d/1lN5Eh2wz_DDOlcI7as9gQcmUALNqs0_y/view?usp=share_link">this data</a>.

# %%
## import the pandas library in this cell
import pandas as pd

# %% [markdown]
# ### Ingest the following dataset into this note:
#
# - ```ems_2019_first_6_months.csv``` into a dataframe named ```ems_19_first_df```

# %%
## import data and store in dataframe
pd.read_csv("wk4-hw-data/ems_2019_first_6_months.csv")
# Out:
#         CAD_INCIDENT_ID    INCIDENT_DATETIME INITIAL_CALL_TYPE  \
# 0             190010111  2019-01-01 00:24:51              SICK
# 1             190010112  2019-01-01 00:25:22              DRUG
# 2             190010113  2019-01-01 00:25:52              DRUG
# 3             190010114  2019-01-01 00:25:52             OBMAJ
# 4             190010115  2019-01-01 00:26:03               EDP
# ...                 ...                  ...               ...
# 754651        190010106  2019-01-01 00:24:12              DRUG
# 754652        190010107  2019-01-01 00:24:14               UNC
# 754653        190010108  2019-01-01 00:24:16            INJMAJ
# 754654        190010109  2019-01-01 00:24:23              CARD
# 754655        190010110  2019-01-01 00:24:35              DRUG
#
#         INITIAL_SEVERITY_LEVEL_CODE FINAL_CALL_TYPE  \
# 0                                 6            SICK
# 1                                 4            DRUG
# 2                                 4            DRUG
# 3                                 3           OBMAJ
# 4                                 7             EDP
# ...                             ...             ...
# 754651                            4            DRUG
# 754652                            2             UNC
# 754653                            3          INJMAJ
# 754654                            3            CARD
# 754655                            4            DRUG
#
#         FINAL_SEVERITY_LEVEL_CODE FIRST_ASSIGNMENT_DATETIME  \
# 0                               6    01/01/2019 12:25:28 AM
# 1                               4    01/01/2019 12:25:39 AM
# 2                               4    01/01/2019 12:25:57 AM
# 3                               3    01/01/2019 12:26:13 AM
# 4                               7    01/01/2019 12:26:12 AM
# ...                           ...                       ...
# 754651                          4    01/01/2019 12:28:52 AM
# 754652                          2    01/01/2019 12:24:38 AM
# 754653                          3    01/01/2019 12:25:50 AM
# 754654                          3    01/01/2019 12:25:08 AM
# 754655                          4    01/01/2019 12:25:28 AM
#
#        VALID_DISPATCH_RSPNS_TIME_INDC  DISPATCH_RESPONSE_SECONDS_QY  \
# 0                                   Y                            37
# 1                                   Y                            17
# 2                                   Y                             5
# 3                                   Y                            21
# 4                                   Y                             9
# ...                               ...                           ...
# 754651                              Y                           280
# 754652                              Y                            24
# 754653                              Y                            94
# 754654                              Y                            45
# 754655                              Y                            53
#
#        FIRST_ACTIVATION_DATETIME  ... POLICEPRECINCT CITYCOUNCILDISTRICT  \
# 0         01/01/2019 12:25:56 AM  ...            9.0                 2.0
# 1         01/01/2019 12:26:03 AM  ...           23.0                 9.0
# 2         01/01/2019 12:26:11 AM  ...           63.0                45.0
# 3         01/01/2019 12:26:24 AM  ...          106.0                32.0
# 4         01/01/2019 12:26:29 AM  ...          101.0                31.0
# ...                          ...  ...            ...                 ...
# 754651    01/01/2019 12:28:52 AM  ...           14.0                 3.0
# 754652    01/01/2019 12:24:57 AM  ...           14.0                 3.0
# 754653    01/01/2019 12:25:50 AM  ...           18.0                 4.0
# 754654    01/01/2019 12:25:27 AM  ...           50.0                14.0
# 754655    01/01/2019 12:25:40 AM  ...           62.0                47.0
#
#         COMMUNITYDISTRICT  COMMUNITYSCHOOLDISTRICT CONGRESSIONALDISTRICT  \
# 0                   103.0                      1.0                  12.0
# 1                   111.0                      4.0                  13.0
# 2                   318.0                     22.0                   8.0
# 3                   410.0                     27.0                   8.0
# 4                   414.0                     27.0                   5.0
# ...                   ...                      ...                   ...
# 754651              105.0                      2.0                  12.0
# 754652              105.0                      2.0                  12.0
# 754653              105.0                      2.0                  12.0
# 754654              208.0                     10.0                  13.0
# 754655              311.0                     20.0                  10.0
#
#        REOPEN_INDICATOR SPECIAL_EVENT_INDICATOR STANDBY_INDICATOR  \
# 0                     N                       N                 N
# 1                     N                       N                 N
# 2                     N                       N                 N
# 3                     N                       N                 N
# 4                     N                       N                 N
# ...                 ...                     ...               ...
# 754651                N                       N                 N
# 754652                N                       N                 N
# 754653                N                       N                 N
# 754654                N                       N                 N
# 754655                N                       N                 N
#
#         TRANSFER_INDICATOR       source
# 0                        N  chunk10.csv
# 1                        N  chunk10.csv
# 2                        N  chunk13.csv
# 3                        N  chunk14.csv
# 4                        N  chunk14.csv
# ...                    ...          ...
# 754651                   N  chunk82.csv
# 754652                   N  chunk82.csv
# 754653                   N  chunk82.csv
# 754654                   N  chunk82.csv
# 754655                   N  chunk82.csv
#
# [754656 rows x 32 columns]

# %%
ems_19_first_df = pd.read_csv("wk4-hw-data/ems_2019_first_6_months.csv")

df
# Out:
#         CAD_INCIDENT_ID    INCIDENT_DATETIME INITIAL_CALL_TYPE  \
# 0             190010111  2019-01-01 00:24:51              SICK
# 1             190010112  2019-01-01 00:25:22              DRUG
# 2             190010113  2019-01-01 00:25:52              DRUG
# 3             190010114  2019-01-01 00:25:52             OBMAJ
# 4             190010115  2019-01-01 00:26:03               EDP
# ...                 ...                  ...               ...
# 754651        190010106  2019-01-01 00:24:12              DRUG
# 754652        190010107  2019-01-01 00:24:14               UNC
# 754653        190010108  2019-01-01 00:24:16            INJMAJ
# 754654        190010109  2019-01-01 00:24:23              CARD
# 754655        190010110  2019-01-01 00:24:35              DRUG
#
#         INITIAL_SEVERITY_LEVEL_CODE FINAL_CALL_TYPE  \
# 0                                 6            SICK
# 1                                 4            DRUG
# 2                                 4            DRUG
# 3                                 3           OBMAJ
# 4                                 7             EDP
# ...                             ...             ...
# 754651                            4            DRUG
# 754652                            2             UNC
# 754653                            3          INJMAJ
# 754654                            3            CARD
# 754655                            4            DRUG
#
#         FINAL_SEVERITY_LEVEL_CODE FIRST_ASSIGNMENT_DATETIME  \
# 0                               6    01/01/2019 12:25:28 AM
# 1                               4    01/01/2019 12:25:39 AM
# 2                               4    01/01/2019 12:25:57 AM
# 3                               3    01/01/2019 12:26:13 AM
# 4                               7    01/01/2019 12:26:12 AM
# ...                           ...                       ...
# 754651                          4    01/01/2019 12:28:52 AM
# 754652                          2    01/01/2019 12:24:38 AM
# 754653                          3    01/01/2019 12:25:50 AM
# 754654                          3    01/01/2019 12:25:08 AM
# 754655                          4    01/01/2019 12:25:28 AM
#
#        VALID_DISPATCH_RSPNS_TIME_INDC  DISPATCH_RESPONSE_SECONDS_QY  \
# 0                                   Y                            37
# 1                                   Y                            17
# 2                                   Y                             5
# 3                                   Y                            21
# 4                                   Y                             9
# ...                               ...                           ...
# 754651                              Y                           280
# 754652                              Y                            24
# 754653                              Y                            94
# 754654                              Y                            45
# 754655                              Y                            53
#
#        FIRST_ACTIVATION_DATETIME  ... POLICEPRECINCT CITYCOUNCILDISTRICT  \
# 0         01/01/2019 12:25:56 AM  ...            9.0                 2.0
# 1         01/01/2019 12:26:03 AM  ...           23.0                 9.0
# 2         01/01/2019 12:26:11 AM  ...           63.0                45.0
# 3         01/01/2019 12:26:24 AM  ...          106.0                32.0
# 4         01/01/2019 12:26:29 AM  ...          101.0                31.0
# ...                          ...  ...            ...                 ...
# 754651    01/01/2019 12:28:52 AM  ...           14.0                 3.0
# 754652    01/01/2019 12:24:57 AM  ...           14.0                 3.0
# 754653    01/01/2019 12:25:50 AM  ...           18.0                 4.0
# 754654    01/01/2019 12:25:27 AM  ...           50.0                14.0
# 754655    01/01/2019 12:25:40 AM  ...           62.0                47.0
#
#         COMMUNITYDISTRICT  COMMUNITYSCHOOLDISTRICT CONGRESSIONALDISTRICT  \
# 0                   103.0                      1.0                  12.0
# 1                   111.0                      4.0                  13.0
# 2                   318.0                     22.0                   8.0
# 3                   410.0                     27.0                   8.0
# 4                   414.0                     27.0                   5.0
# ...                   ...                      ...                   ...
# 754651              105.0                      2.0                  12.0
# 754652              105.0                      2.0                  12.0
# 754653              105.0                      2.0                  12.0
# 754654              208.0                     10.0                  13.0
# 754655              311.0                     20.0                  10.0
#
#        REOPEN_INDICATOR SPECIAL_EVENT_INDICATOR STANDBY_INDICATOR  \
# 0                     N                       N                 N
# 1                     N                       N                 N
# 2                     N                       N                 N
# 3                     N                       N                 N
# 4                     N                       N                 N
# ...                 ...                     ...               ...
# 754651                N                       N                 N
# 754652                N                       N                 N
# 754653                N                       N                 N
# 754654                N                       N                 N
# 754655                N                       N                 N
#
#         TRANSFER_INDICATOR       source
# 0                        N  chunk10.csv
# 1                        N  chunk10.csv
# 2                        N  chunk13.csv
# 3                        N  chunk14.csv
# 4                        N  chunk14.csv
# ...                    ...          ...
# 754651                   N  chunk82.csv
# 754652                   N  chunk82.csv
# 754653                   N  chunk82.csv
# 754654                   N  chunk82.csv
# 754655                   N  chunk82.csv
#
# [754656 rows x 32 columns]

# %%
## call the first 10 rows
df.head(10)
# Out:
#    CAD_INCIDENT_ID    INCIDENT_DATETIME INITIAL_CALL_TYPE  \
# 0        190010111  2019-01-01 00:24:51              SICK
# 1        190010112  2019-01-01 00:25:22              DRUG
# 2        190010113  2019-01-01 00:25:52              DRUG
# 3        190010114  2019-01-01 00:25:52             OBMAJ
# 4        190010115  2019-01-01 00:26:03               EDP
# 5        190073272  2019-01-07 17:49:43               EDP
# 6        190073416  2019-01-07 18:27:54               EDP
# 7        190081434  2019-01-08 10:28:31            UNKNOW
# 8        190081743  2019-01-08 11:43:35            UNKNOW
# 9        190081744  2019-01-08 11:43:48               EDP
#
#    INITIAL_SEVERITY_LEVEL_CODE FINAL_CALL_TYPE  FINAL_SEVERITY_LEVEL_CODE  \
# 0                            6            SICK                          6
# 1                            4            DRUG                          4
# 2                            4            DRUG                          4
# 3                            3           OBMAJ                          3
# 4                            7             EDP                          7
# 5                            7             EDP                          7
# 6                            7             EDP                          7
# 7                            4          UNKNOW                          4
# 8                            4          UNKNOW                          4
# 9                            7             EDP                          7
#
#   FIRST_ASSIGNMENT_DATETIME VALID_DISPATCH_RSPNS_TIME_INDC  \
# 0    01/01/2019 12:25:28 AM                              Y
# 1    01/01/2019 12:25:39 AM                              Y
# 2    01/01/2019 12:25:57 AM                              Y
# 3    01/01/2019 12:26:13 AM                              Y
# 4    01/01/2019 12:26:12 AM                              Y
# 5    01/07/2019 05:49:50 PM                              Y
# 6    01/07/2019 06:28:33 PM                              Y
# 7    01/08/2019 10:29:19 AM                              Y
# 8    01/08/2019 11:43:47 AM                              Y
# 9    01/08/2019 11:43:59 AM                              Y
#
#    DISPATCH_RESPONSE_SECONDS_QY FIRST_ACTIVATION_DATETIME  ... POLICEPRECINCT  \
# 0                            37    01/01/2019 12:25:56 AM  ...            9.0
# 1                            17    01/01/2019 12:26:03 AM  ...           23.0
# 2                             5    01/01/2019 12:26:11 AM  ...           63.0
# 3                            21    01/01/2019 12:26:24 AM  ...          106.0
# 4                             9    01/01/2019 12:26:29 AM  ...          101.0
# 5                             7    01/07/2019 05:50:04 PM  ...           17.0
# 6                            39    01/07/2019 06:28:44 PM  ...            6.0
# 7                            48    01/08/2019 10:29:36 AM  ...            NaN
# 8                            12    01/08/2019 11:43:55 AM  ...            7.0
# 9                            11    01/08/2019 11:44:30 AM  ...           44.0
#
#   CITYCOUNCILDISTRICT  COMMUNITYDISTRICT  COMMUNITYSCHOOLDISTRICT  \
# 0                 2.0              103.0                      1.0
# 1                 9.0              111.0                      4.0
# 2                45.0              318.0                     22.0
# 3                32.0              410.0                     27.0
# 4                31.0              414.0                     27.0
# 5                 5.0              106.0                      2.0
# 6                 3.0              102.0                      2.0
# 7                 NaN                NaN                      NaN
# 8                 1.0              103.0                      2.0
# 9                16.0              204.0                      9.0
#
#   CONGRESSIONALDISTRICT REOPEN_INDICATOR SPECIAL_EVENT_INDICATOR  \
# 0                  12.0                N                       N
# 1                  13.0                N                       N
# 2                   8.0                N                       N
# 3                   8.0                N                       N
# 4                   5.0                N                       N
# 5                  12.0                N                       N
# 6                  10.0                N                       N
# 7                   NaN                N                       N
# 8                  12.0                N                       N
# 9                  15.0                N                       N
#
#   STANDBY_INDICATOR  TRANSFER_INDICATOR        source
# 0                 N                   N   chunk10.csv
# 1                 N                   N   chunk10.csv
# 2                 N                   N   chunk13.csv
# 3                 N                   N   chunk14.csv
# 4                 N                   N   chunk14.csv
# 5                 N                   N  chunk149.csv
# 6                 N                   N  chunk149.csv
# 7                 N                   N  chunk149.csv
# 8                 N                   N  chunk149.csv
# 9                 N                   N  chunk149.csv
#
# [10 rows x 32 columns]

# %%
## call the last 5 rows
df.tail(5)
# Out:
#         CAD_INCIDENT_ID    INCIDENT_DATETIME INITIAL_CALL_TYPE  \
# 754651        190010106  2019-01-01 00:24:12              DRUG
# 754652        190010107  2019-01-01 00:24:14               UNC
# 754653        190010108  2019-01-01 00:24:16            INJMAJ
# 754654        190010109  2019-01-01 00:24:23              CARD
# 754655        190010110  2019-01-01 00:24:35              DRUG
#
#         INITIAL_SEVERITY_LEVEL_CODE FINAL_CALL_TYPE  \
# 754651                            4            DRUG
# 754652                            2             UNC
# 754653                            3          INJMAJ
# 754654                            3            CARD
# 754655                            4            DRUG
#
#         FINAL_SEVERITY_LEVEL_CODE FIRST_ASSIGNMENT_DATETIME  \
# 754651                          4    01/01/2019 12:28:52 AM
# 754652                          2    01/01/2019 12:24:38 AM
# 754653                          3    01/01/2019 12:25:50 AM
# 754654                          3    01/01/2019 12:25:08 AM
# 754655                          4    01/01/2019 12:25:28 AM
#
#        VALID_DISPATCH_RSPNS_TIME_INDC  DISPATCH_RESPONSE_SECONDS_QY  \
# 754651                              Y                           280
# 754652                              Y                            24
# 754653                              Y                            94
# 754654                              Y                            45
# 754655                              Y                            53
#
#        FIRST_ACTIVATION_DATETIME  ... POLICEPRECINCT CITYCOUNCILDISTRICT  \
# 754651    01/01/2019 12:28:52 AM  ...           14.0                 3.0
# 754652    01/01/2019 12:24:57 AM  ...           14.0                 3.0
# 754653    01/01/2019 12:25:50 AM  ...           18.0                 4.0
# 754654    01/01/2019 12:25:27 AM  ...           50.0                14.0
# 754655    01/01/2019 12:25:40 AM  ...           62.0                47.0
#
#         COMMUNITYDISTRICT  COMMUNITYSCHOOLDISTRICT CONGRESSIONALDISTRICT  \
# 754651              105.0                      2.0                  12.0
# 754652              105.0                      2.0                  12.0
# 754653              105.0                      2.0                  12.0
# 754654              208.0                     10.0                  13.0
# 754655              311.0                     20.0                  10.0
#
#        REOPEN_INDICATOR SPECIAL_EVENT_INDICATOR STANDBY_INDICATOR  \
# 754651                N                       N                 N
# 754652                N                       N                 N
# 754653                N                       N                 N
# 754654                N                       N                 N
# 754655                N                       N                 N
#
#         TRANSFER_INDICATOR       source
# 754651                   N  chunk82.csv
# 754652                   N  chunk82.csv
# 754653                   N  chunk82.csv
# 754654                   N  chunk82.csv
# 754655                   N  chunk82.csv
#
# [5 rows x 32 columns]

# %%
## call a 20 random rows
df.sample(20)
# Out:
#         CAD_INCIDENT_ID    INCIDENT_DATETIME INITIAL_CALL_TYPE  \
# 582690        191452500  2019-05-25 15:06:21            PEDSTR
# 494153        191250690  2019-05-05 03:41:50            INJURY
# 510476        191284610  2019-05-08 22:40:35            ALTMEN
# 103130        190290473  2019-01-29 04:27:14            INJURY
# 506814        191280563  2019-05-08 04:56:55              CARD
# 328371        190844146  2019-03-25 21:26:32               EDP
# 260535        190681481  2019-03-09 10:10:43             HYPTN
# 474356        191201979  2019-04-30 13:07:54            INJURY
# 741899        191812660  2019-06-30 14:07:37            INJURY
# 145781        190391466  2019-02-08 10:07:22            SICPED
# 267563        190700811  2019-03-11 06:54:24             OTHER
# 520289        191311019  2019-05-11 06:41:48            INJURY
# 525294        191321755  2019-05-12 11:59:44              CARD
# 221078        190582146  2019-02-27 14:00:40            INJMAJ
# 325497        190841001  2019-03-25 08:17:43             OBMAJ
# 118740        190324482  2019-02-01 23:29:53            DIFFBR
# 482167        191221585  2019-05-02 11:01:01            INJURY
# 210025        190552690  2019-02-24 17:26:20              SICK
# 302696        190782435  2019-03-19 14:52:04               EDP
# 251933        190661005  2019-03-07 09:08:00              SICK
#
#         INITIAL_SEVERITY_LEVEL_CODE FINAL_CALL_TYPE  \
# 582690                            3          PEDSTR
# 494153                            5          INJURY
# 510476                            3          ALTMEN
# 103130                            5          INJURY
# 506814                            3            CARD
# 328371                            7             EDP
# 260535                            7            SICK
# 474356                            5          INJURY
# 741899                            5          INJURY
# 145781                            4          SICPED
# 267563                            6           OTHER
# 520289                            5          INJURY
# 525294                            3            CARD
# 221078                            3          INJMAJ
# 325497                            3           OBMAJ
# 118740                            2            SICK
# 482167                            5          INJURY
# 210025                            6            SICK
# 302696                            7             EDP
# 251933                            6            SICK
#
#         FINAL_SEVERITY_LEVEL_CODE FIRST_ASSIGNMENT_DATETIME  \
# 582690                          3    05/25/2019 03:06:49 PM
# 494153                          5    05/05/2019 03:42:10 AM
# 510476                          3    05/08/2019 10:42:07 PM
# 103130                          5    01/29/2019 04:27:23 AM
# 506814                          3    05/08/2019 04:57:05 AM
# 328371                          7    03/25/2019 09:26:49 PM
# 260535                          6    03/09/2019 10:11:03 AM
# 474356                          5    04/30/2019 01:08:52 PM
# 741899                          5    06/30/2019 02:09:08 PM
# 145781                          4    02/08/2019 10:08:17 AM
# 267563                          6    03/11/2019 06:54:46 AM
# 520289                          5    05/11/2019 06:42:07 AM
# 525294                          3    05/12/2019 12:00:29 PM
# 221078                          3    02/27/2019 02:01:06 PM
# 325497                          3    03/25/2019 08:18:08 AM
# 118740                          6    02/01/2019 11:30:32 PM
# 482167                          5    05/02/2019 11:01:12 AM
# 210025                          6    02/24/2019 05:26:29 PM
# 302696                          7    03/19/2019 02:52:09 PM
# 251933                          6    03/07/2019 09:08:13 AM
#
#        VALID_DISPATCH_RSPNS_TIME_INDC  DISPATCH_RESPONSE_SECONDS_QY  \
# 582690                              Y                            28
# 494153                              Y                            20
# 510476                              Y                            92
# 103130                              Y                             9
# 506814                              Y                            10
# 328371                              Y                            17
# 260535                              Y                            20
# 474356                              Y                            58
# 741899                              Y                            91
# 145781                              Y                            55
# 267563                              Y                            22
# 520289                              Y                            19
# 525294                              Y                            45
# 221078                              Y                            26
# 325497                              Y                            25
# 118740                              Y                            39
# 482167                              Y                            11
# 210025                              Y                             9
# 302696                              Y                             5
# 251933                              Y                            13
#
#        FIRST_ACTIVATION_DATETIME  ... POLICEPRECINCT CITYCOUNCILDISTRICT  \
# 582690                       NaN  ...           46.0                14.0
# 494153    05/05/2019 03:42:17 AM  ...           33.0                10.0
# 510476    05/08/2019 10:42:30 PM  ...           25.0                 9.0
# 103130    01/29/2019 04:27:34 AM  ...          110.0                25.0
# 506814    05/08/2019 04:57:55 AM  ...           34.0                10.0
# 328371    03/25/2019 09:27:05 PM  ...           75.0                42.0
# 260535    03/09/2019 10:11:13 AM  ...           75.0                37.0
# 474356    04/30/2019 01:09:08 PM  ...           30.0                 7.0
# 741899    06/30/2019 02:17:18 PM  ...           42.0                17.0
# 145781    02/08/2019 10:08:33 AM  ...           70.0                40.0
# 267563    03/11/2019 06:54:57 AM  ...          112.0                29.0
# 520289    05/11/2019 06:42:14 AM  ...           47.0                12.0
# 525294    05/12/2019 12:00:52 PM  ...           44.0                 8.0
# 221078    02/27/2019 02:01:21 PM  ...           62.0                43.0
# 325497    03/25/2019 08:18:29 AM  ...           24.0                 7.0
# 118740    02/01/2019 11:30:46 PM  ...           25.0                 8.0
# 482167    05/02/2019 11:01:32 AM  ...           76.0                39.0
# 210025    02/24/2019 05:26:38 PM  ...           69.0                46.0
# 302696    03/19/2019 02:52:42 PM  ...            6.0                 3.0
# 251933    03/07/2019 09:08:21 AM  ...           70.0                40.0
#
#         COMMUNITYDISTRICT  COMMUNITYSCHOOLDISTRICT CONGRESSIONALDISTRICT  \
# 582690              205.0                     10.0                  15.0
# 494153              112.0                      6.0                  13.0
# 510476              111.0                      5.0                  13.0
# 103130              404.0                     24.0                   6.0
# 506814              112.0                      6.0                  13.0
# 328371              305.0                     19.0                   8.0
# 260535              305.0                     19.0                   8.0
# 474356              109.0                      6.0                  13.0
# 741899              203.0                     12.0                  15.0
# 145781              314.0                     22.0                   9.0
# 267563              406.0                     28.0                   6.0
# 520289              212.0                     11.0                  16.0
# 525294              204.0                      9.0                  15.0
# 221078              311.0                     20.0                  11.0
# 325497              107.0                      3.0                  13.0
# 118740              111.0                      4.0                  12.0
# 482167              306.0                     15.0                   7.0
# 210025              318.0                     18.0                   8.0
# 302696              102.0                      2.0                  10.0
# 251933              314.0                     22.0                   9.0
#
#        REOPEN_INDICATOR SPECIAL_EVENT_INDICATOR STANDBY_INDICATOR  \
# 582690                N                       N                 N
# 494153                N                       N                 N
# 510476                N                       N                 N
# 103130                N                       N                 N
# 506814                Y                       N                 N
# 328371                N                       N                 N
# 260535                N                       N                 N
# 474356                N                       N                 N
# 741899                N                       N                 N
# 145781                N                       N                 N
# 267563                N                       N                 N
# 520289                N                       N                 N
# 525294                N                       N                 N
# 221078                N                       N                 N
# 325497                N                       N                 N
# 118740                N                       N                 N
# 482167                N                       N                 N
# 210025                N                       N                 N
# 302696                N                       N                 N
# 251933                N                       N                 N
#
#         TRANSFER_INDICATOR        source
# 582690                   N  chunk155.csv
# 494153                   N  chunk154.csv
# 510476                   N  chunk154.csv
# 103130                   N  chunk150.csv
# 506814                   N  chunk154.csv
# 328371                   N  chunk153.csv
# 260535                   N  chunk152.csv
# 474356                   N  chunk154.csv
# 741899                   N  chunk157.csv
# 145781                   N  chunk151.csv
# 267563                   N  chunk152.csv
# 520289                   N  chunk155.csv
# 525294                   N  chunk155.csv
# 221078                   N  chunk152.csv
# 325497                   N  chunk153.csv
# 118740                   N  chunk151.csv
# 482167                   N  chunk154.csv
# 210025                   N  chunk151.csv
# 302696                   N  chunk152.csv
# 251933                   N  chunk152.csv
#
# [20 rows x 32 columns]

# %%
## get basic overview of the data

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 754656 entries, 0 to 754655
# Data columns (total 32 columns):
#  #   Column                          Non-Null Count   Dtype
# ---  ------                          --------------   -----
#  0   CAD_INCIDENT_ID                 754656 non-null  int64
#  1   INCIDENT_DATETIME               754656 non-null  object
#  2   INITIAL_CALL_TYPE               754656 non-null  object
#  3   INITIAL_SEVERITY_LEVEL_CODE     754656 non-null  int64
#  4   FINAL_CALL_TYPE                 754656 non-null  object
#  5   FINAL_SEVERITY_LEVEL_CODE       754656 non-null  int64
#  6   FIRST_ASSIGNMENT_DATETIME       749544 non-null  object
#  7   VALID_DISPATCH_RSPNS_TIME_INDC  754656 non-null  object
#  8   DISPATCH_RESPONSE_SECONDS_QY    754656 non-null  int64
#  9   FIRST_ACTIVATION_DATETIME       748561 non-null  object
#  10  FIRST_ON_SCENE_DATETIME         729221 non-null  object
#  11  VALID_INCIDENT_RSPNS_TIME_INDC  754656 non-null  object
#  12  INCIDENT_RESPONSE_SECONDS_QY    729068 non-null  float64
#  13  INCIDENT_TRAVEL_TM_SECONDS_QY   729221 non-null  float64
#  14  FIRST_TO_HOSP_DATETIME          522462 non-null  object
#  15  FIRST_HOSP_ARRIVAL_DATETIME     518867 non-null  object
#  16  INCIDENT_CLOSE_DATETIME         754540 non-null  object
#  17  HELD_INDICATOR                  754656 non-null  object
#  18  INCIDENT_DISPOSITION_CODE       748265 non-null  float64
#  19  BOROUGH                         754656 non-null  object
#  20  INCIDENT_DISPATCH_AREA          754656 non-null  object
#  21  ZIPCODE                         745086 non-null  float64
#  22  POLICEPRECINCT                  745102 non-null  float64
#  23  CITYCOUNCILDISTRICT             745071 non-null  float64
#  24  COMMUNITYDISTRICT               745101 non-null  float64
#  25  COMMUNITYSCHOOLDISTRICT         744542 non-null  float64
#  26  CONGRESSIONALDISTRICT           745071 non-null  float64
#  27  REOPEN_INDICATOR                754656 non-null  object
#  28  SPECIAL_EVENT_INDICATOR         754656 non-null  object
#  29  STANDBY_INDICATOR               754656 non-null  object
#  30  TRANSFER_INDICATOR              754656 non-null  object
#  31  source                          754656 non-null  object
# dtypes: float64(9), int64(4), object(19)
# memory usage: 184.2+ MB

# %%
## what datatypes do the different columns hold?
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
## how many rows and columns are there?
754656 rows x 32 columns

# %% [markdown]
# ### In three separate cells, ingest the 3 other related datasets into this notebook:
#
# - ```ems_2019_last_6_months.csv``` into a dataframe named ```ems_19_last_df```
# - ```ems_2020_first_6_months.csv``` into a dataframe named ```ems_20_first_df```
# - ```ems_2020_last_6_months.csv``` into a dataframe named ```ems_20_last_df```
#
# We want to combine all 4 dataframes so we can run an analysis on the combined dataframes

# %%
### For last 6 months of 2019
## call the dataframe to see what you have

ems_19_last_df = pd.read_csv("wk4-hw-data/ems_2019_last_6_months.csv")
ems_19_last_df
# Out:
#         CAD_INCIDENT_ID    INCIDENT_DATETIME INITIAL_CALL_TYPE  \
# 0             191853909  2019-07-04 21:07:53              DRUG
# 1             191864927  2019-07-05 21:09:53            MVAINJ
# 2             191870823  2019-07-06 05:32:12            INJURY
# 3             191870824  2019-07-06 05:33:49               UNC
# 4             191870897  2019-07-06 06:20:26            INJURY
# ...                 ...                  ...               ...
# 781735        192702998  2019-09-27 16:20:29               EDP
# 781736        192704269  2019-09-27 21:05:14             OTHER
# 781737        193012678  2019-10-28 15:01:30            MVAINJ
# 781738        193330212  2019-11-29 01:16:42               EDP
# 781739        193634478  2019-12-29 23:59:34               EDP
#
#         INITIAL_SEVERITY_LEVEL_CODE FINAL_CALL_TYPE  \
# 0                                 4            DRUG
# 1                                 4          MVAINJ
# 2                                 5          INJURY
# 3                                 2             UNC
# 4                                 5          INJURY
# ...                             ...             ...
# 781735                            7          UNKNOW
# 781736                            6           OTHER
# 781737                            4          MVAINJ
# 781738                            7             EDP
# 781739                            7             EDP
#
#         FINAL_SEVERITY_LEVEL_CODE FIRST_ASSIGNMENT_DATETIME  \
# 0                               4    07/04/2019 09:08:16 PM
# 1                               4    07/05/2019 09:10:10 PM
# 2                               5    07/06/2019 05:32:49 AM
# 3                               2    07/06/2019 05:33:57 AM
# 4                               5    07/06/2019 06:20:43 AM
# ...                           ...                       ...
# 781735                          4    09/27/2019 04:21:09 PM
# 781736                          6    09/27/2019 09:05:26 PM
# 781737                          4    10/28/2019 03:01:30 PM
# 781738                          7    11/29/2019 01:17:36 AM
# 781739                          7                       NaN
#
#        VALID_DISPATCH_RSPNS_TIME_INDC  DISPATCH_RESPONSE_SECONDS_QY  \
# 0                                   Y                            23
# 1                                   Y                            17
# 2                                   Y                            37
# 3                                   Y                             8
# 4                                   Y                            17
# ...                               ...                           ...
# 781735                              Y                            40
# 781736                              Y                            12
# 781737                              Y                             0
# 781738                              Y                            54
# 781739                              N                             0
#
#        FIRST_ACTIVATION_DATETIME  ... POLICEPRECINCT CITYCOUNCILDISTRICT  \
# 0         07/04/2019 09:08:26 PM  ...            NaN                 NaN
# 1         07/05/2019 09:10:20 PM  ...            NaN                 NaN
# 2         07/06/2019 05:33:40 AM  ...           47.0                12.0
# 3         07/06/2019 05:34:25 AM  ...           32.0                 9.0
# 4         07/06/2019 06:20:53 AM  ...            NaN                 NaN
# ...                          ...  ...            ...                 ...
# 781735    09/27/2019 04:21:21 PM  ...          100.0                31.0
# 781736    09/27/2019 09:07:15 PM  ...           43.0                18.0
# 781737    10/28/2019 03:01:30 PM  ...          109.0                20.0
# 781738    11/29/2019 01:17:53 AM  ...           28.0                 9.0
# 781739                       NaN  ...           41.0                17.0
#
#         COMMUNITYDISTRICT  COMMUNITYSCHOOLDISTRICT CONGRESSIONALDISTRICT  \
# 0                     NaN                      NaN                   NaN
# 1                     NaN                      NaN                   NaN
# 2                   212.0                     11.0                  16.0
# 3                   110.0                      5.0                  13.0
# 4                     NaN                      NaN                   NaN
# ...                   ...                      ...                   ...
# 781735              414.0                     27.0                   5.0
# 781736              209.0                      8.0                  15.0
# 781737              407.0                     25.0                   6.0
# 781738              110.0                      5.0                  13.0
# 781739              202.0                      8.0                  15.0
#
#        REOPEN_INDICATOR SPECIAL_EVENT_INDICATOR STANDBY_INDICATOR  \
# 0                     N                       N                 N
# 1                     N                       N                 N
# 2                     N                       N                 N
# 3                     N                       N                 N
# 4                     N                       N                 N
# ...                 ...                     ...               ...
# 781735                N                       N                 N
# 781736                N                       N                 N
# 781737                N                       N                 N
# 781738                N                       N                 N
# 781739                N                       N                 N
#
#         TRANSFER_INDICATOR        source
# 0                        N  chunk157.csv
# 1                        N  chunk157.csv
# 2                        N  chunk157.csv
# 3                        N  chunk157.csv
# 4                        N  chunk157.csv
# ...                    ...           ...
# 781735                   N   chunk81.csv
# 781736                   N   chunk81.csv
# 781737                   N   chunk81.csv
# 781738                   N   chunk81.csv
# 781739                   N   chunk81.csv
#
# [781740 rows x 32 columns]

# %%
### For first 6 months of 2020
## call the dataframe to see what you have

ems_20_first_df = pd.read_csv("wk4-hw-data/ems_2020_first_6_months.csv")
ems_20_first_df
# Out:
#         CAD_INCIDENT_ID    INCIDENT_DATETIME INITIAL_CALL_TYPE  \
# 0             201012966  2020-04-10 14:36:07              SICK
# 1             201013858  2020-04-10 17:37:57            SICKFC
# 2             201013897  2020-04-10 17:46:07             HYPTN
# 3             201014048  2020-04-10 18:19:32            SICKFC
# 4             201014049  2020-04-10 18:19:33            INJURY
# ...                 ...                  ...               ...
# 741802        201824116  2020-06-30 23:58:45            INJURY
# 741803        201824117  2020-06-30 23:59:00              DRUG
# 741804        201824118  2020-06-30 23:59:26            INJURY
# 741805        200293244  2020-01-29 17:15:18            UNKNOW
# 741806        200293566  2020-01-29 18:32:45              EDPC
#
#         INITIAL_SEVERITY_LEVEL_CODE FINAL_CALL_TYPE  \
# 0                                 6            SICK
# 1                                 6          SICKFC
# 2                                 7           HYPTN
# 3                                 6          SICKFC
# 4                                 5          INJURY
# ...                             ...             ...
# 741802                            5          INJURY
# 741803                            4            DRUG
# 741804                            5          INJURY
# 741805                            4          UNKNOW
# 741806                            7            EDPC
#
#         FINAL_SEVERITY_LEVEL_CODE FIRST_ASSIGNMENT_DATETIME  \
# 0                               6    04/10/2020 02:36:37 PM
# 1                               6    04/10/2020 05:56:30 PM
# 2                               7    04/10/2020 05:51:43 PM
# 3                               6    04/10/2020 06:19:54 PM
# 4                               5    04/10/2020 06:25:55 PM
# ...                           ...                       ...
# 741802                          5    06/30/2020 11:58:56 PM
# 741803                          4    06/30/2020 11:59:24 PM
# 741804                          5    06/30/2020 11:59:40 PM
# 741805                          4    01/29/2020 05:47:34 PM
# 741806                          7                       NaN
#
#        VALID_DISPATCH_RSPNS_TIME_INDC  DISPATCH_RESPONSE_SECONDS_QY  \
# 0                                   Y                            30
# 1                                   Y                          1113
# 2                                   Y                           336
# 3                                   Y                            22
# 4                                   Y                           382
# ...                               ...                           ...
# 741802                              Y                            11
# 741803                              Y                            24
# 741804                              Y                            14
# 741805                              Y                          1936
# 741806                              N                             0
#
#        FIRST_ACTIVATION_DATETIME  ... POLICEPRECINCT CITYCOUNCILDISTRICT  \
# 0         04/10/2020 02:37:36 PM  ...          101.0                31.0
# 1         04/10/2020 05:56:30 PM  ...           42.0                17.0
# 2         04/10/2020 05:51:47 PM  ...           62.0                43.0
# 3         04/10/2020 06:23:23 PM  ...           52.0                14.0
# 4         04/10/2020 06:26:14 PM  ...          103.0                27.0
# ...                          ...  ...            ...                 ...
# 741802    06/30/2020 11:59:18 PM  ...          106.0                28.0
# 741803    06/30/2020 11:59:40 PM  ...           61.0                47.0
# 741804    06/30/2020 11:59:57 PM  ...           30.0                 7.0
# 741805    01/29/2020 05:47:57 PM  ...           14.0                 4.0
# 741806                       NaN  ...            9.0                 2.0
#
#         COMMUNITYDISTRICT  COMMUNITYSCHOOLDISTRICT CONGRESSIONALDISTRICT  \
# 0                   414.0                     27.0                   5.0
# 1                   203.0                     12.0                  15.0
# 2                   311.0                     20.0                  11.0
# 3                   207.0                     10.0                  13.0
# 4                   412.0                     28.0                   5.0
# ...                   ...                      ...                   ...
# 741802              410.0                     27.0                   5.0
# 741803              315.0                     21.0                  11.0
# 741804              109.0                      6.0                  13.0
# 741805              105.0                      2.0                  12.0
# 741806              102.0                      2.0                  12.0
#
#        REOPEN_INDICATOR SPECIAL_EVENT_INDICATOR STANDBY_INDICATOR  \
# 0                     N                       N                 N
# 1                     N                       N                 N
# 2                     N                       N                 N
# 3                     N                       N                 N
# 4                     N                       N                 N
# ...                 ...                     ...               ...
# 741802                N                       N                 N
# 741803                N                       N                 N
# 741804                N                       N                 N
# 741805                N                       N                 N
# 741806                N                       N                 N
#
#         TRANSFER_INDICATOR        source
# 0                        N  chunk148.csv
# 1                        N  chunk148.csv
# 2                        N  chunk148.csv
# 3                        N  chunk148.csv
# 4                        N  chunk148.csv
# ...                    ...           ...
# 741802                   N  chunk172.csv
# 741803                   N  chunk172.csv
# 741804                   N  chunk172.csv
# 741805                   N   chunk81.csv
# 741806                   N   chunk81.csv
#
# [741807 rows x 32 columns]

# %%
### For last 6 months of 2020
## call the dataframe to see what you have

ems_20_last_df = pd.read_csv("wk4-hw-data/ems_2020_last_6_months.csv")
ems_20_last_df
# Out:
#         CAD_INCIDENT_ID    INCIDENT_DATETIME INITIAL_CALL_TYPE  \
# 0             201853344  2020-07-03 19:51:35            MVAINJ
# 1             201861781  2020-07-04 13:38:45            INJURY
# 2             201862931  2020-07-04 19:06:08            INJURY
# 3             201870048  2020-07-05 00:09:31              SICK
# 4             201870159  2020-07-05 00:31:24              EDPC
# ...                 ...                  ...               ...
# 670750        203664156  2020-12-31 23:58:15            DIFFBR
# 670751        203664157  2020-12-31 23:58:27            INJURY
# 670752        203664158  2020-12-31 23:58:38            CARDBR
# 670753        203664159  2020-12-31 23:58:46            MVAINJ
# 670754        203664161  2020-12-31 23:59:13            CARDBR
#
#         INITIAL_SEVERITY_LEVEL_CODE FINAL_CALL_TYPE  \
# 0                                 4          MVAINJ
# 1                                 5          INJURY
# 2                                 5          INJURY
# 3                                 6            SICK
# 4                                 7            SICK
# ...                             ...             ...
# 670750                            2          DIFFBR
# 670751                            5          INJURY
# 670752                            2          CARDBR
# 670753                            4          MVAINJ
# 670754                            2          CARDBR
#
#         FINAL_SEVERITY_LEVEL_CODE FIRST_ASSIGNMENT_DATETIME  \
# 0                               4    07/03/2020 07:52:54 PM
# 1                               5    07/04/2020 01:38:55 PM
# 2                               5    07/04/2020 07:06:34 PM
# 3                               6                       NaN
# 4                               6                       NaN
# ...                           ...                       ...
# 670750                          2    12/31/2020 11:58:26 PM
# 670751                          5    12/31/2020 11:59:57 PM
# 670752                          2    12/31/2020 11:59:32 PM
# 670753                          4    12/31/2020 11:59:37 PM
# 670754                          2    01/01/2021 12:00:22 AM
#
#        VALID_DISPATCH_RSPNS_TIME_INDC  DISPATCH_RESPONSE_SECONDS_QY  \
# 0                                   Y                            79
# 1                                   Y                            10
# 2                                   Y                            26
# 3                                   N                             0
# 4                                   N                             0
# ...                               ...                           ...
# 670750                              Y                            11
# 670751                              Y                            90
# 670752                              Y                            54
# 670753                              Y                            51
# 670754                              Y                            69
#
#        FIRST_ACTIVATION_DATETIME  ... POLICEPRECINCT CITYCOUNCILDISTRICT  \
# 0         07/03/2020 07:53:13 PM  ...            NaN                 NaN
# 1         07/04/2020 01:39:01 PM  ...           20.0                 3.0
# 2         07/04/2020 07:06:53 PM  ...           60.0                47.0
# 3                            NaN  ...           46.0                14.0
# 4                            NaN  ...           43.0                17.0
# ...                          ...  ...            ...                 ...
# 670750    12/31/2020 11:59:10 PM  ...           79.0                36.0
# 670751    01/01/2021 12:01:00 AM  ...           41.0                17.0
# 670752    12/31/2020 11:59:40 PM  ...           30.0                 7.0
# 670753    01/01/2021 12:01:00 AM  ...           48.0                17.0
# 670754    01/01/2021 12:01:10 AM  ...           77.0                36.0
#
#         COMMUNITYDISTRICT  COMMUNITYSCHOOLDISTRICT CONGRESSIONALDISTRICT  \
# 0                     NaN                      NaN                   NaN
# 1                   107.0                      3.0                  10.0
# 2                   313.0                     21.0                   8.0
# 3                   205.0                     10.0                  15.0
# 4                   209.0                     12.0                  15.0
# ...                   ...                      ...                   ...
# 670750              303.0                     14.0                   7.0
# 670751              202.0                      8.0                  15.0
# 670752              109.0                      6.0                  13.0
# 670753              206.0                     12.0                  15.0
# 670754              308.0                     16.0                   9.0
#
#        REOPEN_INDICATOR SPECIAL_EVENT_INDICATOR STANDBY_INDICATOR  \
# 0                     N                       N                 N
# 1                     N                       N                 N
# 2                     N                       N                 N
# 3                     N                       N                 N
# 4                     N                       N                 N
# ...                 ...                     ...               ...
# 670750                N                       N                 N
# 670751                N                       N                 N
# 670752                N                       N                 N
# 670753                N                       N                 N
# 670754                N                       N                 N
#
#         TRANSFER_INDICATOR        source
# 0                        N  chunk172.csv
# 1                        N  chunk172.csv
# 2                        N  chunk172.csv
# 3                        N  chunk172.csv
# 4                        N  chunk172.csv
# ...                    ...           ...
# 670750                   N  chunk214.csv
# 670751                   N  chunk214.csv
# 670752                   N  chunk214.csv
# 670753                   N  chunk214.csv
# 670754                   N  chunk214.csv
#
# [670755 rows x 32 columns]

# %% [markdown]
# ## Combine the 4 dataframes

# %%
## create a list to combine all 
ems_19_last_df.shape
# Out:
# (781740, 32)

# %%
ems_19_first_df.shape
# Out:
# (754656, 32)

# %%
ems_20_first_df.shape
# Out:
# (741807, 32)

# %%
ems_20_last_df.shape
# Out:
# (670755, 32)

# %%
## combine (concat) the dfs
ems_combine_df = pd.concat([ems_19_first_df,ems_19_last_df,ems_20_first_df,ems_20_last_df])

# %% [markdown]
# #### Programmatically (not with a calculator) confirm that their row totals add up to the correct number

# %%
## how many rows does the combined df have
ems_combine_df.shape
# Out:
# (2948958, 32)

# %%
## get total rows when you add up all the individual dataframes
ems_19_last_df.shape[0] + ems_19_first_df.shape[0] + ems_20_first_df.shape[0] + ems_20_last_df.shape[0] == ems_combine_df.shape[0]
# Out:
# True

# %% [markdown]
# ## Ingest Massive Dataset
#
# Step 1. Open ```global_temps.csv``` in Excel first. What happened?
#
# Step 2. Open this data set in Pandas.

# %%
## import global_temps.csv into a df called temps_df

temps_df = pd.read_csv("wk4-hw-data/global_temps.csv")
temps_df
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /var/folders/x2/9ts5r3qj2s9cp9wqz5wtsvx00000gn/T/ipykernel_65944/2853873505.py in <module>
#       1 ## import global_temps.csv into a df called temps_df
#       2
# ----> 3 temps_df = pd.read_csv("wk4-hw-data/global_temps.csv")
#       4 temps_df
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/io/parsers/readers.py in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, error_bad_lines, warn_bad_lines, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options)
#     676     kwds.update(kwds_defaults)
#     677
# --> 678     return _read(filepath_or_buffer, kwds)
#     679
#     680
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/io/parsers/readers.py in _read(filepath_or_buffer, kwds)
#     573
#     574     # Create the parser.
# --> 575     parser = TextFileReader(filepath_or_buffer, **kwds)
#     576
#     577     if chunksize or iterator:
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/io/parsers/readers.py in __init__(self, f, engine, **kwds)
#     930
#     931         self.handles: IOHandles | None = None
# --> 932         self._engine = self._make_engine(f, self.engine)
#     933
#     934     def close(self):
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/io/parsers/readers.py in _make_engine(self, f, engine)
#    1214             # "Union[str, PathLike[str], ReadCsvBuffer[bytes], ReadCsvBuffer[str]]"
#    1215             # , "str", "bool", "Any", "Any", "Any", "Any", "Any"
# -> 1216             self.handles = get_handle(  # type: ignore[call-overload]
#    1217                 f,
#    1218                 mode,
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/io/common.py in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     784         if ioargs.encoding and "b" not in ioargs.mode:
#     785             # Encoding
# --> 786             handle = open(
#     787                 handle,
#     788                 ioargs.mode,
#
# FileNotFoundError: [Errno 2] No such file or directory: 'wk4-hw-data/global_temps.csv'

# %% [markdown]
# ## How many rows of data does this dataset have?

# %%
## How many rows?
temps_df.shape[0]
# Out:
# 2906327

# %% [markdown]
# ## Targeting an Excel sheet
#
# We need the Customs and Border Protection data in this ```multi-data.xlsx``` workbook.
#
# Note that this is an excerpt of the actual CBP data.

# %%
### import it here
cbp_df = pd.read_csv("wk4-hw-data/multi-data.xlsx")
# Out:
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# /var/folders/x2/9ts5r3qj2s9cp9wqz5wtsvx00000gn/T/ipykernel_65944/3533530390.py in <module>
#       1 ### import it here
# ----> 2 cbp_df = pd.read_csv("wk4-hw-data/multi-data.xlsx")
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/io/parsers/readers.py in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, error_bad_lines, warn_bad_lines, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options)
#     676     kwds.update(kwds_defaults)
#     677
# --> 678     return _read(filepath_or_buffer, kwds)
#     679
#     680
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/io/parsers/readers.py in _read(filepath_or_buffer, kwds)
#     573
#     574     # Create the parser.
# --> 575     parser = TextFileReader(filepath_or_buffer, **kwds)
#     576
#     577     if chunksize or iterator:
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/io/parsers/readers.py in __init__(self, f, engine, **kwds)
#     930
#     931         self.handles: IOHandles | None = None
# --> 932         self._engine = self._make_engine(f, self.engine)
#     933
#     934     def close(self):
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/io/parsers/readers.py in _make_engine(self, f, engine)
#    1232
#    1233         try:
# -> 1234             return mapping[engine](f, **self.options)
#    1235         except Exception:
#    1236             if self.handles is not None:
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/io/parsers/c_parser_wrapper.py in __init__(self, src, **kwds)
#      73
#      74         kwds["dtype"] = ensure_dtype_objs(kwds.get("dtype", None))
# ---> 75         self._reader = parsers.TextReader(src, **kwds)
#      76
#      77         self.unnamed_cols = self._reader.unnamed_cols
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader.__cinit__()
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader._get_header()
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader._tokenize_rows()
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/_libs/parsers.pyx in pandas._libs.parsers.raise_parser_error()
#
# UnicodeDecodeError: 'utf-8' codec can't decode byte 0x98 in position 16: invalid start byte

# %%
## call the top 15 rows
